# %% [markdown]
# <a href="https://colab.research.google.com/github/acb100cias/econometriaLEDS/blob/main/correlacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as  pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns

# %%
enigh=pd.read_csv('/content/concentradohogar.csv')

# %%
enigh.keys().values

# %%
T1=enigh.filter(['educa_jefe','ing_cor'])

# %%
T1.educa_jefe.values.min()

# %%
C=np.corrcoef(T1.educa_jefe,T1.ing_cor)

# %%
T1.plot.scatter(x='educa_jefe',y='ing_cor')

# %%
T2=enigh.filter(['educa_jefe','sexo_jefe'])

# %%
T2

# %%
C2=np.corrcoef(T2.educa_jefe,T2.sexo_jefe)

# %%
C2

# %%
T2.plot.scatter(x='sexo_jefe',y='educa_jefe')

# %%
T3=enigh.filter(['ing_cor','sexo_jefe','edad_jefe','educa_jefe'])

# %%
C3=np.corrcoef(T3.ing_cor,T3.sexo_jefe)

# %%
C3

# %%
C4=np.corrcoef(T3.ing_cor,T3.edad_jefe)

# %%
C4

# %%
C5=np.corrcoef(T3.educa_jefe,T3.edad_jefe)

# %%
C5

# %%
T3.plot.scatter(x='edad_jefe',y='educa_jefe')

# %%
T3.corr()

# %%
enigh.corr()

# %%
T4=enigh.filter(['ing_cor','gasto_mon'])

# %%
T4

# %%
T4.plot.scatter(x='ing_cor',y='gasto_mon')

# %%
T4.corr()

# %%
T5=enigh.filter(['ing_cor','deudas'])

# %%
T5.corr()

# %%
T5.plot.scatter(x='ing_cor',y='deudas')

# %%
plt.imshow(enigh.corr(),cmap='hot',interpolation='nearest')
plt.colorbar()
